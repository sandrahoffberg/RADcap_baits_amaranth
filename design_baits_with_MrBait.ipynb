# %% [markdown]
# # Use Amaranth 3RAD data to design sequence capture baits for a RADcap project.

# %% [markdown]
# Rerunning MrBait with the newest version of ipyrad (0.9.54) <br>
# June 15, 2020

# %%
# import packages into python
import ipyrad as ip
import ipyrad.analysis as ipa

# print the version of ipyrad you are running
print('ipyrad', ipa.__version__)
# Out:
# ipyrad 0.9.54

# %% [markdown]
# ### This is how I pooled together the reads from each species

# %%
#!/bin/sh
#SBATCH --account=eaton
# SBATCH --exclusive
#SBATCH --time=11:59:00
#SBATCH --workdir=/moto/eaton/users/sandra/
#SBATCH --job-name=cat
#SBATCH --mail-type=END
#SBATCH --mail-user=sandra.hoffberg@columbia.edu


mkdir /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/
mkdir /moto/eaton/users/sandra/Just_pooled_species_fixed/

cd /moto/eaton/users/sandra/cat_runs_after_i7/demux_inner_stacks/decloned/rename/

cat SLH_AL_0001_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/acanthochiton_pooled_R1_.fq.gz
cat SLH_AL_0003_R1_.fq.gz SLH_AL_0004_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/acutilobus_pooled_R1_.fq.gz
cat SLH_AL_0006_R1_.fq.gz SLH_AL_0009_R1_.fq.gz SLH_AL_0010_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/albus_pooled_R1_.fq.gz
cat SLH_AL_0013_R1_.fq.gz SLH_AL_0018_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/arenicola_pooled_R1_.fq.gz
cat SLH_AL_0019_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/asplundii_pooled_R1_.fq.gz
cat SLH_AL_0020_R1_.fq.gz SLH_AL_0021_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/australis_pooled_R1_.fq.gz
cat SLH_AL_0023_R1_.fq.gz SLH_AL_0028_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/blitoides_pooled_R1_.fq.gz
cat SLH_AL_0029_R1_.fq.gz SLH_AL_0034_R1_.fq.gz SLH_AL_0037_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/blitum_pooled_R1_.fq.gz
cat SLH_AL_0039_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/californicus_pooled_R1_.fq.gz
cat SLH_AL_0040_R1_.fq.gz SLH_AL_0041_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/cannabinus_pooled_R1_.fq.gz
cat SLH_AL_0102_R1_.fq.gz SLH_AL_0110_R1_.fq.gz SLH_AL_0116_R1_.fq.gz SLH_AL_0322_R1_.fq.gz SLH_AL_0540_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/caudatus_pooled_R1_.fq.gz
cat SLH_AL_0599_R1_.fq.gz SLH_AL_0600_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/crassipes_pooled_R1_.fq.gz
cat SLH_AL_0679_R1_.fq.gz SLH_AL_0699_R1_.fq.gz SLH_AL_0728_R1_.fq.gz SLH_AL_0804_R1_.fq.gz SLH_AL_0832_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/cruentus_pooled_R1_.fq.gz
cat SLH_AL_0951_R1_.fq.gz SLH_AL_0952_R1_.fq.gz SLH_AL_0955_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/deflexus_pooled_R1_.fq.gz
cat SLH_AL_0965_R1_.fq.gz SLH_AL_0979_R1_.fq.gz SLH_AL_0992_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/dubius_pooled_R1_.fq.gz
cat SLH_AL_0997_R1_.fq.gz SLH_AL_0998_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/fimbriatus_pooled_R1_.fq.gz
cat SLH_AL_1000_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/floridanus_pooled_R1_.fq.gz
cat SLH_AL_1009_R1_.fq.gz SLH_AL_1013_R1_.fq.gz SLH_AL_1014_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/graecizans_pooled_R1_.fq.gz
cat SLH_AL_1015_R1_.fq.gz SLH_AL_1016_R1_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed
R2_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/tricolor_pooled_R2_.fq.gz
cat SLH_AL_3003_R2_.fq.gz SLH_AL_3017_R2_.fq.gz SLH_AL_3027_R2_.fq.gz SLH_AL_3045_R2_.fq.gz SLH_AL_0009-restricted_R2_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/tuberculatus_pooled_R2_.fq.gz
cat SLH_AL_3047_R2_.fq.gz SLH_AL_3062_R2_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/viridis_pooled_R2_.fq.gz
cat SLH_AL_3066_R2_.fq.gz SLH_AL_3067_R2_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/wrightii_pooled_R2_.fq.gz
cat SLH_AL_3065_R2_.fq.gz > /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/watsonii_pooled_R2_.fq.gz
cp SLH_AL_0088-contemp_R2_.fq.gz /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/
cp SLH_AL_0095-contemp_R2_.fq.gz /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/
cp SLH_AL_0026-contemp_R2_.fq.gz /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/
cp SLH_AL_0101-contemp_R2_.fq.gz /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/
cp SLH_AL_0024-contemp_R2_.fq.gz /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/


cp /moto/eaton/users/sandra/Pooled_species_Palmeri_fixed/* /moto/eaton/users/sandra/Just_pooled_species_fixed/

# %% [markdown]
# Then delete the contemp samples from folder Just_pooled_species_fixed

# %%
#Since the names are ok already, don't need this cell
# load accession:species dataframe
spnames = pd.read_csv("/moto/eaton/projects/RAW_DATA/Amaranthus/Amaranth_sample_names.csv")

# subset only rows with species names not empty
spnames = spnames[spnames.Species.notna()]
spnames.Species = [i.split("-")[0] for i in spnames.Species]

# convert dataframe to a dictionary 
pdict = {spnames.Sample[i]: spnames.Species[i] for i in spnames.index}

#create a merged assembly
pooled = ip.merge(
    name="pooled-spp33", 
    assemblies=[lib1, lib2, lib3, lib4],
    rename_dict=pdict,
    )

keep = [i for i in pooled.samples if "SLH" not in i]
pooled = pooled.branch("pooled-spp33", subsamples=keep, force=True)
pooled.save()

# %%
HardMask = "/moto/eaton/users/slh2181/reference/Ahypochondriacus_459_v2.0.hardmasked.fa"

# set params on this assembly
pooled = ip.Assembly("pooled_9_45")
pooled.params.sorted_fastq_path = "/moto/eaton/users/slh2181/Just_pooled_species_fixed/*"
pooled.params.project_dir = "/moto/eaton/users/slh2181/MrBait"
pooled.params.assembly_method = "reference"
pooled.params.reference_sequence = HardMask
pooled.params.restriction_overhang = ("ATCGG", "TAGCTT")
pooled.params.datatype = "pair3rad"
pooled.params.phred_Qscore_offset = 43
pooled.params.max_barcode_mismatch = 1
pooled.params.filter_adapters = 3
pooled.params.max_alleles_consens = 3
pooled.params.max_SNPs_locus = 0.5
pooled.params.mindepth_majrule = 2
pooled.params.mindepth_statistical = 6
pooled.params.min_samples_locus = 4
pooled.params.max_Hs_consens = 0.5
pooled.params.max_Ns_consens = 0.2
pooled.params.max_shared_Hs_locus = 0.4
pooled.params.max_Indels_locus = 12
pooled.params.output_formats = "psl"
pooled.hackersonly.max_inner_mate_distance = 1000
pooled.params.max_low_qual_bases = 6

pooled.params
# Out:
# New Assembly: pooled_9_45
# 0   assembly_name               pooled_9_45
# 1   project_dir                 /moto/eaton/users/slh2181/MrBait
# 2   raw_fastq_path
# 3   barcodes_path
# 4   sorted_fastq_path           /moto/eaton/users/slh2181/Just_pooled_species_fixed/*
# 5   assembly_method             reference
# 6   reference_sequence          /moto/eaton/users/slh2181/reference/Ahypochondriacus_459_v2.0.hardmasked.fa
# 7   datatype                    pair3rad
# 8   restriction_overhang        ('ATCGG', 'TAGCTT')
# 9   max_low_qual_bases          6
# 10  phred_Qscore_offset         43
# 11  mindepth_statistical        6
# 12  mindepth_majrule            2
# 13  maxdepth                    10000
# 14  clust_threshold             0.85
# 15  max_barcode_mismatch        1
# 16  filter_adapters             3
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         3
# 19  max_Ns_consens              0.2
# 20  max_Hs_consens              0.5
# ...

# %%
! awk 1 /home/sandra/Files/MrBait/hypochondriacus_cpDNA.fasta /home/sandra/Files/MrBait/Ahypochondriacus_459_v2.0.hardmasked.fa > /home/sandra/Files/MrBait/cp_nuclear_hardmask_genomes.fa

! awk '!/^>/ {printf "%s", $0; n = "\n"} /^>/ {print n $0; n = ""}' /home/sandra/Files/MrBait/cp_nuclear_hardmask_genomes.fa | fold -w 60 > /home/sandra/Files/MrBait/cp_nuclear_hardmask_genomes2.fa

! echo "" >> /home/sandra/Files/MrBait/cp_nuclear_hardmask_genomes2.fa

# %%
cpHardMask = "/home/sandra/Files/MrBait/cp_nuclear_hardmask_genomes2.fa"

# set params on this assembly
pooled = ip.Assembly("pooled_9_54")
pooled.params.sorted_fastq_path = "/home/sandra/Files/Just_pooled_species_fixed/*"
pooled.params.project_dir = "/home/sandra/Files/MrBait"
pooled.params.assembly_method = "reference"
pooled.params.reference_sequence = cpHardMask
pooled.params.restriction_overhang = ("ATCGG", "TAGCTT")
pooled.params.datatype = "pair3rad"
pooled.params.phred_Qscore_offset = 43
pooled.params.max_barcode_mismatch = 1
pooled.params.filter_adapters = 3
pooled.params.max_alleles_consens = 3
pooled.params.max_SNPs_locus = 0.5
pooled.params.mindepth_majrule = 2
pooled.params.mindepth_statistical = 6
pooled.params.min_samples_locus = 4
pooled.params.max_Hs_consens = 0.5
pooled.params.max_Ns_consens = 0.2
pooled.params.max_shared_Hs_locus = 0.4
pooled.params.max_Indels_locus = 12
pooled.params.output_formats = "psl"
#pooled.hackersonly.max_inner_mate_distance = 1000
pooled.params.max_low_qual_bases = 6

pooled.params
# Out:
# New Assembly: pooled_9_54
# 0   assembly_name               pooled_9_54
# 1   project_dir                 ~/Files/MrBait
# 2   raw_fastq_path
# 3   barcodes_path
# 4   sorted_fastq_path           ~/Files/Just_pooled_species_fixed/*
# 5   assembly_method             reference
# 6   reference_sequence          ./cp_nuclear_hardmask_genomes2.fa
# 7   datatype                    pair3rad
# 8   restriction_overhang        ('ATCGG', 'TAGCTT')
# 9   max_low_qual_bases          6
# 10  phred_Qscore_offset         43
# 11  mindepth_statistical        6
# 12  mindepth_majrule            2
# 13  maxdepth                    10000
# 14  clust_threshold             0.85
# 15  max_barcode_mismatch        1
# 16  filter_adapters             3
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         3
# 19  max_Ns_consens              0.2
# 20  max_Hs_consens              0.5
# 21  min_samples_locus           4
# 22  max_SNPs_locus              0.5
# 23  max_Indels_locus            12
# ...

# %%
# run assembly
pooled.run("1234567", force=True, auto=True)
# Out:
# Parallel connection | pinky: 80 cores
# [####################] 100% 0:00:30 | loading reads        | s1 |
# [####################] 100% 0:12:37 | processing reads     | s2 |
# [####################] 100% 0:05:30 | indexing reference   | s3 |
# [####################] 100% 0:01:18 | join unmerged pairs  | s3 |
# [####################] 100% 0:00:16 | dereplicating        | s3 |
# [####################] 100% 0:00:05 | splitting dereps     | s3 |
# [####################] 100% 0:08:22 | mapping reads        | s3 |
# [####################] 100% 0:49:55 | building clusters    | s3 |
# [####################] 100% 0:00:10 | calc cluster stats   | s3 |
# [####################] 100% 0:12:57 | inferring [H, E]     | s4 |
# [####################] 100% 0:00:09 | calculating depths   | s5 |
# [####################] 100% 0:00:17 | chunking clusters    | s5 |
# [####################] 100% 0:11:10 | consens calling      | s5 |
# [####################] 100% 0:01:44 | indexing alleles     | s5 |
# ...

# %%
pooled.stats_dfs.s7_samples
# Out:
#                       sample_coverage
# reference                       37316
# acanthochiton_pooled             9782
# acutilobus_pooled               16142
# albus_pooled                    14578
# arenicola_pooled                17120
# ...                               ...
# tricolor_pooled                 12541
# tuberculatus_pooled             17567
# viridis_pooled                  11861
# watsonii_pooled                  9017
# wrightii_pooled                 14325
#
# [34 rows x 1 columns]

# %% [markdown]
# ### How many loci on each chromosome?

# %%
data = "/home/sandra/Files/MrBait/pooled_9_54_outfiles/pooled_9_54.seqs.hdf5"
chro = ipa.window_extracter(data)
chro.scaffold_table.head(20)
# Out:
#                                     scaffold_name  scaffold_length
# 0   KX279888_1_A_hypo_chloroplast_complete_genome           150518
# 1                                     Scaffold_10         22670516
# 2                                     Scaffold_11         22280117
# 3                                     Scaffold_12         22052327
# 4                                     Scaffold_13         20679869
# 5                                     Scaffold_14         20190685
# 6                                     Scaffold_15         17522127
# 7                                     Scaffold_16         16951160
# 8                                      Scaffold_1         38124660
# 9                                      Scaffold_2         35657244
# 10                                     Scaffold_3         30204323
# 11                                     Scaffold_4         28349311
# 12                                     Scaffold_5         25672467
# ...

# %%
chro = ipa.window_extracter(data, 
                            name="cp",
                            workdir="/home/sandra/Files/MrBait",
                           scaffold_idxs=[0])
chro.run()
chro.stats
# Out:
# Wrote data to /home/sandra/Files/MrBait/cp.phy
#                                                  scaffold  start   end  sites  \
# prefilter   KX279888_1_A_hypo_chloroplast_complete_genome      0  None  13318
# postfilter  KX279888_1_A_hypo_chloroplast_complete_genome      0  None  10228
#
#             snps  missing  samples
# prefilter    102     0.71       34
# postfilter    98     0.65       34

# %%
rax = ipa.raxml(data = "/home/sandra/Files/MrBait/cp.phy", name="cp_RAX", workdir="/home/sandra/Files/MrBait",T=80, N=100, m="GTRGAMMA" )

# %%
rax.run()
# Out:
# job cp_RAX finished successfully

# %%
import toytree

tre = toytree.tree("/home/sandra/Files/MrBait/RAxML_bipartitions.cp_RAX")
tre.root(["quitensis_pooled","caudatus_pooled","dubius_pooled","spinosus_pooled","reference","cruentus_pooled",
          "hybridus_pooled","hypochondriacus_pooled","wrightii_pooled","retroflexus_pooled","powellii_pooled","acutilobus_pooled"]).draw(use_edge_lengths=False)
# Out:
# (<toyplot.canvas.Canvas at 0x7ff84fa8fa90>,
#  <toyplot.coordinates.Cartesian at 0x7ff84d1d57d0>)
# ...

# %% [markdown]
# # Start with MrBait

# %%
! mrbait -h
# Out:
# ...
# 	    MrBait: Universal Probe Design for Targeted-Enrichment Methods
# ...
#
# 	Version:  1.2.6
# 	Author:   Tyler K. Chafin
# 	Contact:  tkchafin@uark.edu
# 	License:  GNU Public License v3.0
#
# 	Releases: https://github.com/tkchafin/mrbait/releases
#
# 	Citation: Chafin TK, Douglas MR, Douglas ME. 2018. MrBait: Universal
# 		identification and design of targeted-enrichment capture probes.
# 		Bioinformatics. https://doi.org/10.1093/bioinformatics/bty548
#
# 	Source code: https://github.com/tkchafin/mrbait
# 	Documentation: https://mrbait.readthedocs.io/
# 	Conda package: https://anaconda.org/tylerkchafin/mrbait
#
# ...
#
#
# 	Parsing command line arguments...
# 	Exiting because help menu was called.
#
# MrBait Help Menu
#
# For more detailed information, please see the manual.
#
#
# Usage:
#
# 	 /moto/home/slh2181/miniconda3/bin/mrbait -A </path/to/MAF> <-c><-l><-t><...>
#
# Description:
#
# 	MrBait is a program for designing baits for targeted enrichment studies
# ...

# %% [markdown]
# ## This is what I submited for the baits, March 23, 2020

# %%
#All but cpDNA
#--db bait_no_cp.sqlite --resume 4
# varmax=3, len=135: 2500 targets

! mrbait -T 24 --vthreads 24 -L /moto/eaton/users/slh2181/MrBait/pooled_9_45_outfiles/pooled_9_45.loci --cov 5 -l 100 --thresh 0.15 -Q 0.55 --mask 0.15 --max_mask 0.55 -b 90 --var_max 3 --numN 1 --numG 1 --mult_reg --min_mult 200 --dist_r 50 --flank_dist 50 --select_r cons --filter_r snp=1,15 -s calc=2,20 --filter_r pw=0.8,0.8 --filter_b pw=0.8,0.8 --filter_r gc=0.25,0.75 --filter_b gc=0.25,0.75 --print_loc --print_tr --out bait_no_cp_9_45 --consens_maf 0.2 --filter_r len=125,9999 --dustMask --blastx_fdb /moto/eaton/users/slh2181/reference/hypochondriacus_cpDNA.fasta --filter_b blast_x=0.8,0.8 --fastadb /moto/eaton/users/slh2181/reference/Ahypochondriacus_459_v2.0.fa --filter_r blast_i=0.5,0.5 --filter_b blast_a=0.8,0.8
# Out:
# ...
# 	    MrBait: Universal Probe Design for Targeted-Enrichment Methods
# ...
#
# 	Version:  1.2.6
# 	Author:   Tyler K. Chafin
# 	Contact:  tkchafin@uark.edu
# 	License:  GNU Public License v3.0
#
# 	Releases: https://github.com/tkchafin/mrbait/releases
#
# 	Citation: Chafin TK, Douglas MR, Douglas ME. 2018. MrBait: Universal
# 		identification and design of targeted-enrichment capture probes.
# 		Bioinformatics. https://doi.org/10.1093/bioinformatics/bty548
#
# 	Source code: https://github.com/tkchafin/mrbait
# 	Documentation: https://mrbait.readthedocs.io/
# 	Conda package: https://anaconda.org/tylerkchafin/mrbait
#
# ...
#
#
# 	Parsing command line arguments...
# 	Loading SQLite Database...
# 		Establishing database connection: /moto/eaton/users/slh2181/MrBait/bait_no_cp_9_45.sqlite
# 		Initializing empty tables.
#
# 		### Runtime: 0:00:00 (0.771315 seconds) ###
#
# 	Step 1: Loading Alignments
# 		Step 1 parameters:
# 			Minimum alignment depth (-c): 5
# 			Minimum alignment length (-l): 100
# ...

# %% [markdown]
# #### This was the older thing using the assembly from the old version of ipyrad

# %%
#All but cpDNA...THIS
#--db bait_no_cp.sqlite --resume 4
# varmax=2, len=125: 2000 targets

! mrbait -T 24 --vthreads 24 -L /moto/eaton/users/slh2181/MrBait/pooled-spp33_Hardmask_format.loci --cov 6 -l 100 --thresh 0.15 -Q 0.55 --mask 0.15 --max_mask 0.55 -b 90 --var_max 2 --numN 0 --numG 1 --mult_reg --min_mult 200 --dist_r 50 --flank_dist 50 --select_r cons --filter_r snp=1,15 -s calc=2,20 --filter_r pw=0.8,0.8 --filter_b pw=0.8,0.8 --filter_r gc=0.27,0.73 --filter_b gc=0.27,0.73 --print_loc --print_tr --out bait_no_cp --consens_maf 0.2 --filter_r len=125,9999 --dustMask --blastx_fdb /moto/eaton/users/slh2181/reference/hypochondriacus_cpDNA.fasta --filter_b blast_x=0.8,0.8 --fastadb /moto/eaton/users/slh2181/reference/Ahypochondriacus_459_v2.0.fa --filter_r blast_i=0.5,0.5 --filter_b blast_a=0.8,0.8
# Out:
# ...
# 	    MrBait: Universal Probe Design for Targeted-Enrichment Methods
# ...
#
# 	Version:  1.2.6
# 	Author:   Tyler K. Chafin
# 	Contact:  tkchafin@uark.edu
# 	License:  GNU Public License v3.0
#
# 	Releases: https://github.com/tkchafin/mrbait/releases
#
# 	Citation: Chafin TK, Douglas MR, Douglas ME. 2018. MrBait: Universal
# 		identification and design of targeted-enrichment capture probes.
# 		Bioinformatics. https://doi.org/10.1093/bioinformatics/bty548
#
# 	Source code: https://github.com/tkchafin/mrbait
# 	Documentation: https://mrbait.readthedocs.io/
# 	Conda package: https://anaconda.org/tylerkchafin/mrbait
#
# ...
#
#
# 	Parsing command line arguments...
# 	Loading SQLite Database...
# 		Establishing database connection: /moto/eaton/users/slh2181/MrBait/bait_no_cp.sqlite
# 		Initializing empty tables.
#
# 		### Runtime: 0:00:00 (0.654878 seconds) ###
#
# 	Step 1: Loading Alignments
# 		Step 1 parameters:
# 			Minimum alignment depth (-c): 6
# 			Minimum alignment length (-l): 100
# ...

# %% [markdown]
# ## This is what I submited for chloroplast baits

# %%
# for cpDNA
#! mrbait -T 24 -L /moto/eaton/users/slh2181/MrBait/pooled-spp33_Hardmask_format.loci --cov 2 -l 100 --thresh 0.25 -Q 0.75 --mask 0.25 --max_mask 0.75 -b 90 --var_max 7 --numN 2 --numG 2 --mult_reg --min_mult 200 --dist_r 50 --flank_dist 50 --select_r cons --filter_r snp=1,25 -s calc=4,50 --filter_r gc=0.27,0.73 --filter_r pw=0.9,0.9 --print_loc --print_tr --out bait_only_cp --vthreads 24 --consens_maf 0.2 --fastadb /moto/eaton/users/slh2181/reference/hypochondriacus_cpDNA.fasta --filter_b blast_i=0.9,0.9 --nodust  
#--dustMask   --filter_b pw=0.2,0.2 --filter_b gc=0.1,0.9 
#--filter_r len=100,9999 

! mrbait -T 24 --vthreads 24 -L /moto/eaton/users/slh2181/MrBait/pooled_9_45_outfiles/pooled_9_45.loci --cov 2 -l 100 --thresh 0.15 -Q 0.55 --mask 0.15 --max_mask 0.55 -b 90 --var_max 3 --numN 1 --numG 1 --mult_reg --min_mult 200 --dist_r 50 --flank_dist 50 --select_r cons --filter_r snp=1,20 -s calc=2,20 --filter_r pw=0.8,0.8 --filter_b pw=0.8,0.8 --filter_r gc=0.25,0.75 --filter_b gc=0.25,0.75 --print_loc --print_tr --out bait_cp_only_9_45 --consens_maf 0.2 --filter_r len=100,9999 --dustMask --fastadb /moto/eaton/users/slh2181/reference/hypochondriacus_cpDNA.fasta --filter_b blast_x=0.8,0.8 --blastx_fdb /moto/eaton/users/slh2181/reference/Ahypochondriacus_459_v2.0.fa --filter_r blast_i=0.4,0.4 #--filter_b blast_a=0.2,0.2
# Out:
# ...
# 	    MrBait: Universal Probe Design for Targeted-Enrichment Methods
# ...
#
# 	Version:  1.2.6
# 	Author:   Tyler K. Chafin
# 	Contact:  tkchafin@uark.edu
# 	License:  GNU Public License v3.0
#
# 	Releases: https://github.com/tkchafin/mrbait/releases
#
# 	Citation: Chafin TK, Douglas MR, Douglas ME. 2018. MrBait: Universal
# 		identification and design of targeted-enrichment capture probes.
# 		Bioinformatics. https://doi.org/10.1093/bioinformatics/bty548
#
# 	Source code: https://github.com/tkchafin/mrbait
# 	Documentation: https://mrbait.readthedocs.io/
# 	Conda package: https://anaconda.org/tylerkchafin/mrbait
#
# ...
#
#
# 	Parsing command line arguments...
# 	Loading SQLite Database...
# 		Establishing database connection: /moto/eaton/users/slh2181/MrBait/bait_cp_only_9_45.sqlite
# 		Initializing empty tables.
#
# 		### Runtime: 0:00:00 (0.022743 seconds) ###
#
# 	Step 1: Loading Alignments
# 		Step 1 parameters:
# 			Minimum alignment depth (-c): 2
# 			Minimum alignment length (-l): 100
# ...

# %% [markdown]
# #### This was the older thing using the assembly from the old version of ipyrad

# %%
# for cpDNA
#! mrbait -T 24 -L /moto/eaton/users/slh2181/MrBait/pooled-spp33_Hardmask_format.loci --cov 2 -l 100 --thresh 0.25 -Q 0.75 --mask 0.25 --max_mask 0.75 -b 90 --var_max 7 --numN 2 --numG 2 --mult_reg --min_mult 200 --dist_r 50 --flank_dist 50 --select_r cons --filter_r snp=1,25 -s calc=4,50 --filter_r gc=0.27,0.73 --filter_r pw=0.9,0.9 --print_loc --print_tr --out bait_only_cp --vthreads 24 --consens_maf 0.2 --fastadb /moto/eaton/users/slh2181/reference/hypochondriacus_cpDNA.fasta --filter_b blast_i=0.9,0.9 --nodust  
#--dustMask   --filter_b pw=0.2,0.2 --filter_b gc=0.1,0.9 
#--filter_r len=100,9999 

! mrbait -T 24 --vthreads 24 -L /moto/eaton/users/slh2181/MrBait/pooled-spp33_Hardmask_format.loci --cov 2 -l 100 --thresh 0.15 -Q 0.55 --mask 0.15 --max_mask 0.55 -b 90 --var_max 3 --numN 1 --numG 1 --mult_reg --min_mult 200 --dist_r 50 --flank_dist 50 --select_r cons --filter_r snp=1,20 -s calc=2,20 --filter_r pw=0.8,0.8 --filter_b pw=0.8,0.8 --filter_r gc=0.27,0.73 --filter_b gc=0.27,0.73 --print_loc --print_tr --out bait_cp_only --consens_maf 0.2 --filter_r len=100,9999 --dustMask --fastadb /moto/eaton/users/slh2181/reference/hypochondriacus_cpDNA.fasta --filter_b blast_x=0.8,0.8 --blastx_fdb /moto/eaton/users/slh2181/reference/Ahypochondriacus_459_v2.0.fa --filter_r blast_i=0.4,0.4 #--filter_b blast_a=0.2,0.2
# Out:
# ...
# 	    MrBait: Universal Probe Design for Targeted-Enrichment Methods
# ...
#
# 	Version:  1.2.6
# 	Author:   Tyler K. Chafin
# 	Contact:  tkchafin@uark.edu
# 	License:  GNU Public License v3.0
#
# 	Releases: https://github.com/tkchafin/mrbait/releases
#
# 	Citation: Chafin TK, Douglas MR, Douglas ME. 2018. MrBait: Universal
# 		identification and design of targeted-enrichment capture probes.
# 		Bioinformatics. https://doi.org/10.1093/bioinformatics/bty548
#
# 	Source code: https://github.com/tkchafin/mrbait
# 	Documentation: https://mrbait.readthedocs.io/
# 	Conda package: https://anaconda.org/tylerkchafin/mrbait
#
# ...
#
#
# 	Parsing command line arguments...
# 	Loading SQLite Database...
# 		Establishing database connection: /moto/eaton/users/slh2181/MrBait/bait_cp_only.sqlite
# 		Initializing empty tables.
#
# 		### Runtime: 0:00:06 (6.211091 seconds) ###
#
# 	Step 1: Loading Alignments
# 		Step 1 parameters:
# 			Minimum alignment depth (-c): 2
# 			Minimum alignment length (-l): 100
# ...

# %% [markdown]
# # Redoing with looser GC content...

# %%
#nuclear DNA
! mrbait -T 70 --vthreads 70 -L /home/sandra/Files/MrBait/pooled_9_54_outfiles/pooled_9_54.loci --cov 5 -l 100 --thresh 0.15 -Q 0.55 --mask 0.15 --max_mask 0.55 -b 90 --var_max 3 --numN 1 --numG 1 --mult_reg --min_mult 200 --dist_r 30 --flank_dist 50 --select_r cons --filter_r snp=1,15 -s tile=45 --filter_r pw=0.8,0.8 --filter_b pw=0.8,0.8 --filter_r gc=0.2,0.8 --filter_b gc=0.2,0.8 --print_loc --print_tr --out bait_no_cp_18jun2020 --consens_maf 0.2 --filter_r len=125,9999 --dustMask --blastx_fdb /home/sandra/Files/MrBait/hypochondriacus_cpDNA.fasta --filter_b blast_x=0.8,0.8 --fastadb /home/sandra/Files/MrBait/Ahypochondriacus_459_v2.0.fa --filter_r blast_i=0.5,0.5 --filter_b blast_a=0.8,0.8
# Out:
# ...
# 	    MrBait: Universal Probe Design for Targeted-Enrichment Methods
# ...
#
# 	Version:  1.2.6
# 	Author:   Tyler K. Chafin
# 	Contact:  tkchafin@uark.edu
# 	License:  GNU Public License v3.0
#
# 	Releases: https://github.com/tkchafin/mrbait/releases
#
# 	Citation: Chafin TK, Douglas MR, Douglas ME. 2018. MrBait: Universal
# 		identification and design of targeted-enrichment capture probes.
# 		Bioinformatics. https://doi.org/10.1093/bioinformatics/bty548
#
# 	Source code: https://github.com/tkchafin/mrbait
# 	Documentation: https://mrbait.readthedocs.io/
# 	Conda package: https://anaconda.org/tylerkchafin/mrbait
#
# ...
#
#
# 	Parsing command line arguments...
# 	Loading SQLite Database...
# 		Establishing database connection: /home/sandra/Files/MrBait/bait_no_cp_18jun2020.sqlite
# 		Initializing empty tables.
#
# 		### Runtime: 0:00:00 (0.012478 seconds) ###
#
# 	Step 1: Loading Alignments
# 		Step 1 parameters:
# 			Minimum alignment depth (-c): 5
# 			Minimum alignment length (-l): 100
# ...

# %%
#nuclear DNA ** This one was sent to Brian
! mrbait -T 55 --vthreads 55 -L /pinky/sandra/MrBait/pooled_9_54_outfiles/pooled_9_54.loci --cov 5 -l 100 --thresh 0.15 -Q 0.55 --mask 0.15 --max_mask 0.55 -b 90 --var_max 3 --numN 1 --numG 1 --mult_reg --min_mult 200 --dist_r 30 --flank_dist 50 --select_r cons --filter_r snp=1,15 -s tile=45 --filter_r pw=0.8,0.8 --filter_b pw=0.8,0.8 --filter_r gc=0.2,0.8 --filter_b gc=0.2,0.8 --print_loc --print_tr --out bait_no_cp_29jun2020 --consens_maf 0.2 --filter_r len=125,9999 --dustMask --blastx_fdb /pinky/sandra/MrBait/hypochondriacus_cpDNA.fasta --filter_b blast_x=0.8,0.8 --fastadb /pinky/sandra/MrBait/Ahypochondriacus_459_v2.0.fa --filter_r blast_i=0.5,0.5 --filter_b blast_a=0.8,0.8
# Out:
# ...
# 	    MrBait: Universal Probe Design for Targeted-Enrichment Methods
# ...
#
# 	Version:  1.2.6
# 	Author:   Tyler K. Chafin
# 	Contact:  tkchafin@uark.edu
# 	License:  GNU Public License v3.0
#
# 	Releases: https://github.com/tkchafin/mrbait/releases
#
# 	Citation: Chafin TK, Douglas MR, Douglas ME. 2018. MrBait: Universal
# 		identification and design of targeted-enrichment capture probes.
# 		Bioinformatics. https://doi.org/10.1093/bioinformatics/bty548
#
# 	Source code: https://github.com/tkchafin/mrbait
# 	Documentation: https://mrbait.readthedocs.io/
# 	Conda package: https://anaconda.org/tylerkchafin/mrbait
#
# ...
#
#
# 	Parsing command line arguments...
# 	Loading SQLite Database...
# 		Establishing database connection: /pinky/sandra/MrBait/bait_no_cp_29jun2020.sqlite
# 		Initializing empty tables.
#
# 		### Runtime: 0:00:00 (0.264752 seconds) ###
#
# 	Step 1: Loading Alignments
# 		Step 1 parameters:
# 			Minimum alignment depth (-c): 5
# 			Minimum alignment length (-l): 100
# ...

# %%
#cpDNDA
! mrbait -T 70 --vthreads 70 -L /pinky/sandra/MrBait/pooled_9_54_outfiles/pooled_9_54.loci --cov 2 -l 100 --thresh 0.15 -Q 0.55 --mask 0.15 --max_mask 0.55 -b 90 --var_max 3 --numN 1 --numG 1 --mult_reg --min_mult 200 --dist_r 30 --flank_dist 50 --select_r cons --filter_r snp=1,20 -s tile=45 --filter_r pw=0.8,0.8 --filter_b pw=0.8,0.8 --filter_r gc=0.1,0.9 --filter_b gc=0.1,0.9 --print_loc --print_tr --out bait_cp_26jun2020 --consens_maf 0.3 --filter_r len=100,9999 --dustMask --fastadb /pinky/sandra/MrBait/hypochondriacus_cpDNA.fasta --filter_b blast_x=0.8,0.8 --blastx_fdb /pinky/sandra/MrBait/Ahypochondriacus_459_v2.0.fa --filter_r blast_i=0.4,0.4 --filter_b blast_a=0.6,0.6
# Out:
# ...
# 	    MrBait: Universal Probe Design for Targeted-Enrichment Methods
# ...
#
# 	Version:  1.2.6
# 	Author:   Tyler K. Chafin
# 	Contact:  tkchafin@uark.edu
# 	License:  GNU Public License v3.0
#
# 	Releases: https://github.com/tkchafin/mrbait/releases
#
# 	Citation: Chafin TK, Douglas MR, Douglas ME. 2018. MrBait: Universal
# 		identification and design of targeted-enrichment capture probes.
# 		Bioinformatics. https://doi.org/10.1093/bioinformatics/bty548
#
# 	Source code: https://github.com/tkchafin/mrbait
# 	Documentation: https://mrbait.readthedocs.io/
# 	Conda package: https://anaconda.org/tylerkchafin/mrbait
#
# ...
#
#
# 	Parsing command line arguments...
# 	Loading SQLite Database...
# 		Establishing database connection: /pinky/sandra/MrBait/bait_cp_26jun2020.sqlite
# 		Initializing empty tables.
#
# 		### Runtime: 0:00:00 (0.659766 seconds) ###
#
# 	Step 1: Loading Alignments
# 		Step 1 parameters:
# 			Minimum alignment depth (-c): 2
# 			Minimum alignment length (-l): 100
# ...

# %%
#cpDNDA - no limit to locus length
! mrbait -T 70 --vthreads 70 -L /pinky/sandra/MrBait/pooled_9_54_outfiles/pooled_9_54.loci --cov 2 -l 100 --thresh 0.15 -Q 0.55 --mask 0.15 --max_mask 0.55 -b 90 --var_max 3 --numN 1 --numG 1 --mult_reg --min_mult 200 --dist_r 30 --flank_dist 50 --select_r cons --filter_r snp=1,20 -s tile=45 --filter_r pw=0.8,0.8 --filter_b pw=0.8,0.8 --filter_r gc=0.1,0.9 --filter_b gc=0.1,0.9 --print_loc --print_tr --out bait_cp_26jun2020 --consens_maf 0.2 --dustMask --fastadb /pinky/sandra/MrBait/hypochondriacus_cpDNA.fasta --filter_b blast_x=0.8,0.8 --blastx_fdb /pinky/sandra/MrBait/Ahypochondriacus_459_v2.0.fa --filter_r blast_i=0.4,0.4 --filter_b blast_a=0.6,0.6
# Out:
# ...
# 	    MrBait: Universal Probe Design for Targeted-Enrichment Methods
# ...
#
# 	Version:  1.2.6
# 	Author:   Tyler K. Chafin
# 	Contact:  tkchafin@uark.edu
# 	License:  GNU Public License v3.0
#
# 	Releases: https://github.com/tkchafin/mrbait/releases
#
# 	Citation: Chafin TK, Douglas MR, Douglas ME. 2018. MrBait: Universal
# 		identification and design of targeted-enrichment capture probes.
# 		Bioinformatics. https://doi.org/10.1093/bioinformatics/bty548
#
# 	Source code: https://github.com/tkchafin/mrbait
# 	Documentation: https://mrbait.readthedocs.io/
# 	Conda package: https://anaconda.org/tylerkchafin/mrbait
#
# ...
#
#
# 	Parsing command line arguments...
# 	Loading SQLite Database...
# 		Establishing database connection: /pinky/sandra/MrBait/bait_cp_26jun2020.sqlite
# 		Initializing empty tables.
#
# 		### Runtime: 0:00:00 (0.783029 seconds) ###
#
# 	Step 1: Loading Alignments
# 		Step 1 parameters:
# 			Minimum alignment depth (-c): 2
# 			Minimum alignment length (-l): 100
# ...

# %%
#cpDNDA - no limit to locus length
# ** This one was sent to Brian
! mrbait -T 80 --vthreads 80 -L /pinky/sandra/MrBait/pooled_9_54_outfiles/pooled_9_54.loci --cov 1 -l 100 --thresh 0.15 -Q 0.55 --mask 0.15 --max_mask 0.55 -b 90 --var_max 3 --numN 1 --numG 1 --mult_reg --min_mult 200 --dist_r 30 --flank_dist 50 --select_r cons --filter_r snp=1,20 -s tile=45 --filter_r pw=0.8,0.8 --filter_b pw=0.8,0.8 --filter_r gc=0.1,0.9 --filter_b gc=0.1,0.9 --print_loc --print_tr --out bait_cp_26jun2020 --consens_maf 0.2 --dustMask --fastadb /pinky/sandra/MrBait/hypochondriacus_cpDNA.fasta --filter_b blast_x=0.8,0.8 --blastx_fdb /pinky/sandra/MrBait/Ahypochondriacus_459_v2.0.fa --filter_r blast_i=0.4,0.4 --filter_b blast_a=0.6,0.6
# Out:
# ...
# 	    MrBait: Universal Probe Design for Targeted-Enrichment Methods
# ...
#
# 	Version:  1.2.6
# 	Author:   Tyler K. Chafin
# 	Contact:  tkchafin@uark.edu
# 	License:  GNU Public License v3.0
#
# 	Releases: https://github.com/tkchafin/mrbait/releases
#
# 	Citation: Chafin TK, Douglas MR, Douglas ME. 2018. MrBait: Universal
# 		identification and design of targeted-enrichment capture probes.
# 		Bioinformatics. https://doi.org/10.1093/bioinformatics/bty548
#
# 	Source code: https://github.com/tkchafin/mrbait
# 	Documentation: https://mrbait.readthedocs.io/
# 	Conda package: https://anaconda.org/tylerkchafin/mrbait
#
# ...
#
#
# 	Parsing command line arguments...
# 	Loading SQLite Database...
# 		Establishing database connection: /pinky/sandra/MrBait/bait_cp_26jun2020.sqlite
# 		Initializing empty tables.
#
# 		### Runtime: 0:00:01 (1.504638 seconds) ###
#
# 	Step 1: Loading Alignments
# 		Step 1 parameters:
# 			Minimum alignment depth (-c): 1
# 			Minimum alignment length (-l): 100
# ...
